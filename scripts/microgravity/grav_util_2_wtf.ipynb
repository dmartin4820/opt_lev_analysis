# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import grav_util_2 as gu2

# %%
import bead_util as bu
import calib_util as cal
import transfer_func_util as tf
import configuration as config

# %%
import grav_util_2 as gu2

# %%
theory_data_dir = '/data/grav_sim_data/2um_spacing_data/'
data_dir = '/data/20180704/bead1/grav_data/shield_1s_1h'
no_bead_dir = '/data/20180704/no_bead/grav_data/shield_1s_1h_lower_p'
many_s_many_h = '/data/20180704/bead1/grav_data/shield'

# %%
datafiles = bu.find_all_fnames(data_dir, ext=config.extensions['data'])
datafiles_no_bead = bu.find_all_fnames(no_bead_dir, ext=config.extensions['data'])
datafiles_msmh = bu.find_all_fnames(many_s_many_h, ext=config.extensions['data'])
# Out:
# Finding files in:
# /data/20180704/bead1/grav_data/shield_1s_1h
# Found 2946 files...
# Finding files in:
# /data/20180704/no_bead/grav_data/shield_1s_1h_lower_p
# Found 219 files...
# Finding files in:
# /data/20180704/bead1/grav_data/shield
# Found 5740 files...

# %%
reload(gu2)
Nf = 2945
AD2 = gu2.AggregateData(datafiles[:Nf])
AD2.load_grav_funcs(theory_data_dir)
Data = AD2.getDataFrames()
# Out:
# [------------------------------------------]   0.0% ... Processing 2945 files
# [------------------------------------------]   0.0% ... Processing 2945 files
# [------------------------------------------]   0.1% ... Processing 2945 files
# [------------------------------------------]   0.1% ... Processing 2945 files
# [------------------------------------------]   0.1% ... Processing 2945 files
# [------------------------------------------]   0.2% ... Processing 2945 files
# [------------------------------------------]   0.2% ... Processing 2945 files
# [------------------------------------------]   0.2% ... Processing 2945 files
# [------------------------------------------]   0.3% ... Processing 2945 files
# [------------------------------------------]   0.3% ... Processing 2945 files
# [------------------------------------------]   0.3% ... Processing 2945 files
# [------------------------------------------]   0.4% ... Processing 2945 files
# ...

# %%
Nf = 300
AD4 = gu2.AggregateData(datafiles_msmh[:Nf])
AD4.load_grav_funcs(theory_data_dir)
Data_msmh = AD4.getDataFrames()
# Out:
# [-------------------------------------------]   0.0% ... Processing 300 files
# [-------------------------------------------]   0.3% ... Processing 300 files
# [-------------------------------------------]   0.7% ... Processing 300 files
# [-------------------------------------------]   1.0% ... Processing 300 files
# [#------------------------------------------]   1.3% ... Processing 300 files
# [#------------------------------------------]   1.7% ... Processing 300 files
# [#------------------------------------------]   2.0% ... Processing 300 files
# [#------------------------------------------]   2.3% ... Processing 300 files
# [#------------------------------------------]   2.7% ... Processing 300 files
# [#------------------------------------------]   3.0% ... Processing 300 files
# [#------------------------------------------]   3.3% ... Processing 300 files
# [##-----------------------------------------]   3.7% ... Processing 300 files
# ...

# %%
import dill as pickle
pickle.dump(Data, open("single_position_data.p", 'wb'))
pickle.dump(Data_msmh, open("many_s_many_h_reduced.p", 'wb'))

# %%
def rms(array):
    return np.sqrt(np.sum(np.abs(array)**2, axis = -1))

# %%
Data_msmh[0][:1]
# Out:
#    ax1pos                        ...                                                                 fft_errors
# 0    67.0                        ...                          [[(4.594219852495808e-13+0j), (2.9796093602052...
#
# [1 rows x 6 columns]

# %%
rmsarr = []
for i in Data_msmh[0].index:
    rmsarr.append(np.sqrt(np.sum(np.abs(Data_msmh[0]['fft_data'].at[i])**2, axis = -1)))

errarr = []
for i in Data_msmh[0].index:
    errarr.append(np.sqrt(np.sum(np.abs(Data_msmh[0]['fft_errors'].at[i])**2, axis = -1)))

# %%
rmsarr = np.array(rmsarr)
errarr = np.array(errarr)

# %%
Data_msmh[0]['xrms'] = rmsarr[:, 0]
Data_msmh[0]['yrms'] = rmsarr[:, 1]
Data_msmh[0]['zrms'] = rmsarr[:, 2]
Data_msmh[0]['xrms_err'] = errarr[:, 0]
Data_msmh[0]['yrms_err'] = errarr[:, 1]
Data_msmh[0]['zrms_err'] = errarr[:, 2]

# %%
Data_msmh[0].plot(y = 'xrms', x = 'ax1pos', style = 'o')
plt.show()

# %%
np.sum((Data_msmh[0].ax1pos ==67.0)*(Data_msmh[0].ax2pos ==25.0))
# Out:
# 3

# %%
NFFT = 250000.
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(Data_msmh[0].ax1pos, Data_msmh[0].ax2pos, Data_msmh[0].xrms*2./NFFT)
plt.show()

# %%
f, axarr = plt.subplots(1, 1)
zrs = Data_msmh[0].ax2pos.round()
for z in np.sort(zrs.unique()):
    y = Data_msmh[0][zrs == z].xrms*2./NFFT
    x = 80-Data_msmh[0][zrs == z].ax1pos+16
    args = range(len(x))
    e = Data_msmh[0][zrs == z].xrms_err*2./NFFT
    if len(y)*len(x)*len(e):
        axarr.errorbar(x, y, e, fmt = '.', label = "realative z = " + str(20 - z) + r"$\mu m$")
axarr.legend(loc = 1)
axarr.set_xlabel(r"separation [$\mu m$]")
axarr.set_ylabel("RMS force at cantilever drive and harmonics [N]")
plt.show()

# %%
Nfnb = 200
#AD3 = gu2.AggregateData(datafiles_no_bead[:Nfnb])
#AD3.load_grav_funcs(theory_data_dir)
Datanb = AD3.getDataFrames()

# %%
prat = 280./148. #inverse power ratio for no bead data

# %%
temp = np.copy(Datanb[1].templates[0][48])

# %%
reload(la)
on_basis = la.normalize_basis(la.make_3don_basis(temp), temp)
fftdatanb = np.copy(Datanb[0]["fft_data"])
fft_transnb = la.apply_trans_all_data(on_basis, fftdatanb)

# %%
re_dat = np.real(fft_trans)
im_dat = np.imag(fft_trans)
abs_datnb = np.abs(fft_transnb)
ortho_projnb = np.sqrt(np.sum(abs_datnb[:, :, 1:]**2, axis = -1))

# %%
plt.plot(re_dat[:200,0,0],'x', label = "signal bead")
plt.plot(re_datnb[:,0,0]*prat,'x', label = "signal nobead")
#plt.plot(ortho_projnb[:, 0], '.', label = "orthogonal background amp")
plt.xlabel("time[m]")
plt.ylabel(r'$\alpha(\lambda_{25\mu m})$')
plt.legend()
plt.show()

# %%
for i in np.arange(3, -1, -1):
    if i==0:
        plt.plot(re_datnb[:200, 1, i], 'x',label = "signal template" + " no bead")
    else:
        plt.plot(re_datnb[:200, 1, i], '.',label = "basis vector "+str(i) + "no bead")
plt.legend()
plt.xlabel("time[m]")
plt.ylabel(r"amplitude [$\alpha(\lambda_{25\mu m})$]")
#plt.show()

# %%
df_re = pd.DataFrame(re_dat[:, 0, :], columns = list('0123456789')+['10'])
df_im = pd.DataFrame(im_dat[:, 0, :], columns = list('0123456789')+['10'])

# %%
np.stack(([1, 2, 3], [4, 5, 6], [7, 8, 9]), axis=-1)[:, 1]
# Out:
# array([4, 5, 6])

# %%
dat_arr = np.array(df_re)
plt.plot(dat_arr[:, 0], '.', label = "component 0 = real template amplitude")
plt.plot(dat_arr[:, 1], '.', label = "component 1")
plt.plot(dat_arr[:, 2], '.', label = "component 2")
plt.legend()
plt.xlabel("time[m]")
plt.ylabel(r"$\alpha$")
plt.show()

# %%
lst = [1]
lst.append(2)
lst
# Out:
# [1, 2]

# %%
re_errors = df_re.sem().values
re_means = df_re.mean().values
im_errors = df_im.sem().values
im_means = df_im.mean().values

# %%
plt.errorbar(np.arange(11), re_means, re_errors, fmt = '.', label = 'real')
plt.errorbar(np.arange(11), im_means, im_errors, fmt = '.', label = 'imaginary')
plt.legend()
plt.xlabel('Basis vector number')
plt.ylabel(r'$\alpha(\lambda_{25 \mu m})$')
plt.show()

# %%
def compute_uncertainty(lambind, Data, ind = 0, m_columns = list('123456789')+['10']):
    temp = np.copy(Data[1].templates[0][lambind])
    on_basis = la.normalize_basis(la.make_3don_basis(temp), temp)
    fftdata = np.copy(Data[0]["fft_data"])
    fft_trans = la.apply_trans_all_data(on_basis, fftdata)
    df_re = pd.DataFrame(np.real(fft_trans[:, ind, :]), columns = list('0123456789')+['10'])
    df_im = pd.DataFrame(np.imag(fft_trans[:, ind, :]), columns = list('0123456789')+['10'])
    means = np.concatenate([df_re[m_columns].mean().values, df_im[m_columns].mean()])
    return df_re['0'].mean(), means.std()

# %%
sigx = []
alphax = []
for i in range(100):
    a, s = compute_uncertainty(i, Data)
    alphax.append(np.abs(a))
    sigx.append(s)

sigy = []
alphay = []
for i in range(100):
    a, s = compute_uncertainty(i, Data, ind = 1)
    alphay.append(np.abs(a))
    sigy.append(s)

# %%
decca_path = "/home/arider/limit_data/just_decca.csv"
pre_decca_path = "/home/arider/limit_data/pre_decca.csv"
pre_decca = np.loadtxt(pre_decca_path, delimiter = ',', skiprows = 1)
decca = np.loadtxt(decca_path, delimiter = ',', skiprows = 1)
plt.loglog(pre_decca[:, 0], pre_decca[:, 1], label = "pre decca")
plt.loglog(decca[:, 0], decca[:, 1], label = "decca")

# %%
#plt.loglog(AD2.lambdas, alphax, label = r"$\alpha_{x}$")
#plt.loglog(AD2.lambdas, alphay, label = r"$\alpha_{y}$")
plt.loglog(AD2.lambdas, 1.96*np.array(sigx), label = r"this analysis 95% cl")
#plt.loglog(AD2.lambdas, sigy, '.', label = r"$\sigma_{y}$")
plt.ylabel(r"$|\alpha|$")
plt.xlabel(r"$\lambda[m]$")
plt.legend()
plt.show()

# %%
re_temp = np.real(temp)
im_temp = np.imag(temp)
f, axarr = plt.subplots(3, 1, sharex = True)
labels = ["x", "y", "z"]
for i, ax in enumerate(axarr):
    ax.plot(re_temp[i, :], 'o', label = labels[i] + " real")
    ax.plot(im_temp[i, :], 'x', label = labels[i] + " imaginary")
    ax.legend()
    ax.set_xlabel("harmonic number")
    ax.set_ylabel("amplitude [N*s]")
plt.show()

# %%
dat0 = Data[0].fft_data[0]
re_dat = np.real(dat0)
im_dat = np.imag(dat0)
f, axarr = plt.subplots(3, 1, sharex = True)
labels = ["x", "y", "z"]
for i, ax in enumerate(axarr):
    ax.plot(re_dat[i, :], 'o', label = labels[i] + " real")
    ax.plot(im_dat[i, :], 'x', label = labels[i] + " imaginary")
    ax.legend()
    ax.set_xlabel("harmonic number")
    ax.set_ylabel("amplitude [N*s]")
plt.show()
